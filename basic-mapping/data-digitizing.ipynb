# %% [markdown]
# <a href="https://colab.research.google.com/github/kaylib4/gis-project-portfolio-geo441-geo541b/blob/main/basic-mapping/data-digitizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Entry & Digitizing**

# %% [markdown]
# Created by Kayli Brown
#
# 09/19/2025

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ##**Digitized Township Map**

# %% [markdown]
# Below is a map of May Township prepared following the Week 4 Assignment Guide
#
# ```markdown
# https://drive.google.com/file/d/1AL2Fm9xxRgX5H6QWe_Q6AkXfjg8cSB8s/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1AL2Fm9xxRgX5H6QWe_Q6AkXfjg8cSB8s
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![township map](https://drive.google.com/uc?export=view&id=1AL2Fm9xxRgX5H6QWe_Q6AkXfjg8cSB8s)
# ```
#
# <mark>Insert the map below:</mark>
#
# ![township map](https://drive.google.com/uc?export=view&id=1AL2Fm9xxRgX5H6QWe_Q6AkXfjg8cSB8s)

# %% [markdown]
# ##**Digitized Subdivision Map**

# %% [markdown]
# Below is a map of the digitized subdivision prepared following the Week 4 Assignment Guide
#
# ```markdown
# https://drive.google.com/file/d/1fX5_xEZrWy-vwUzfczaAqsXxItb0qJ2j/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1fX5_xEZrWy-vwUzfczaAqsXxItb0qJ2j
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![township map](https://drive.google.com/uc?export=view&id=1fX5_xEZrWy-vwUzfczaAqsXxItb0qJ2j)
# ```
#
# <mark>Insert the map below:</mark>
# ![township map](https://drive.google.com/uc?export=view&id=1fX5_xEZrWy-vwUzfczaAqsXxItb0qJ2j)

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure the notebook is viewable by anyone with the link, then <mark>**submit the shareable link to Canvas for the Week 4 Assignment.**</mark>

# %% [markdown]
# ## **References**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
